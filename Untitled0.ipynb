# %% [markdown]
# <a href="https://colab.research.google.com/github/Nulenka/9_sem_GB_pandas/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 57

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_test.csv')

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# # Task 59

# %% [markdown]
# Проверить есть ли в файле пустые значения
# Показать ***median_house_value*** где ***median_income < 2***
# Показать данные в первых 2 столбцах
# Выбрать данные где ***housing_median_age < 20*** и ***median_house_value > 70000***

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df['median_house_value'][df['median_income'] < 2]
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df.loc[df['median_income'] < 2, 'median_house_value']
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
 df[['longitude', 'latitude']]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
 df[['longitude', 'latitude']]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df[(df['housing_median_age'] < 20) & (df['median_house_value'] > 70000)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.loc[(df['housing_median_age'] < 20) & (df['median_house_value'] > 70000), :]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# # Task 61

# %% [markdown]
# Определить какое максимальное и минимальное значение ***median_house_value***
#
# Показать максимальное ***median_house_value***, где ***median_income = 3.1250***
#
# Узнать какая максимальная ***population*** в зоне минимального значения ***median_house_value***

# %%
df['median_house_value'].min()
# Out:
# 22500.0

# %% [markdown]
# ## Seminar 10

# %% [markdown]
# ## Task 63

# %% [markdown]
# 1. Изобразите отношение **households** к **population** с помощью точечного графика
# 2. Визуализировать longitude по отношения к **median_house_value**, используя линейный график
# 3. Представить гистограмму по **housing_median_age**
# 4. Изобразить гистограмму по **median_house_value** с оттенком **housing_median_age**

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x='households', y='population')
# Out:
# <AxesSubplot:xlabel='households', ylabel='population'>

# %%
sns.relplot(data=df, x='median_house_value',y='longitude')

# %%
sns.lineplot(data=df, x='median_house_value',y='longitude')
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='longitude'>

# %%
sns.lineplot(x="longitude", y="median_house_value", data=df)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='median_house_value'>

# %%
sns.histplot(data=df, x='housing_median_age')
# Out:
# <AxesSubplot:xlabel='housing_median_age', ylabel='Count'>

# %%
sns.histplot(data=df, x='median_house_value', hue='housing_median_age')
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>

# %% [markdown]
# # Task 65

# %% [markdown]
# Написать EDA для датасета про пингвинов. Необходимо:
# 1. Использовать 2-3 точечных графика.
# 2. Применить доп измерение в точечных графиках, используя аргументы hue, size, stile.
# 3. Использовать PairGrid с типом графика на ваш выбор.
# 4. Использовать 2-3 гистограммы.
#
# Чтобы подключить датасет с пингвинами, воспользуйтесь данным скриптом:
# penguins = sns.load_dataset("penguins")
# penguins.head()

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.lineplot(x="sex", y="body_mass_g", data=penguins)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='body_mass_g'>

# %%
sns.lineplot(x="species", y="body_mass_g", data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='sex', size=5)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='body_mass_g', size=5)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.histplot(data=penguins, x="bill_length_mm", hue="island")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
g = sns.PairGrid(penguins[['bill_length_mm', 'bill_depth_mm', 'body_mass_g', 'sex']])
g.map(sns.scatterplot)

# %% [markdown]
# # Task 67

# %% [markdown]
# Создать новый столбец в таблице с пингвинми, который будет отвечать за показатель длины клюва пингвина. high (from 42), middle (35-42), low (up to 35).
# ((скрипт про одключение датасета))

# %%
penguins.loc[penguins['bill_length_mm'] < 35, 'type_bill'] = 'low'
penguins.loc[(penguins['bill_length_mm'] >= 35) & (penguins['bill_length_mm'] <= 42), 'type_bill'] = 'middle'
penguins.loc[penguins['bill_length_mm'] > 42, 'type_bill'] = 'high'
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex type_bill
# 0         3750.0    Male    middle
# ...

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# type_bill             2
# dtype: int64

# %% [markdown]
# # Task 69

# %% [markdown]
# Изобразить гистограмму по flipper_length_mm с оттенком heighgt_grup.
# Сделать анализ.

# %%
sns.histplot(data=penguins, x='flipper_length_mm', hue='type_bill')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ## ДЗ

# %%
pd.get_dummies(data)
